# %% [markdown]
# ## Description: This program uses the dual moving average crossover to determine when to buy or sell stocks

# %%
# Importing Libraries
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import yfinance as yf

# This shows an example of the "fivethirtyeight" styling, which tries to 
# replicate the styles from FiveThirtyEight.com.
plt.style.use("fivethirtyeight")

# %%
# Importing and storing the Data
USD = yf.download("USD", "2019-07-14", "2020-07-15")

# https://pypi.org/project/yfinance/
#Shows the data
USD
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2019-07-15  44.139999  44.820000  44.139999  44.439999  44.139736   30200
# 2019-07-16  44.139999  44.139999  43.240002  43.509998  43.216019    7200
# 2019-07-17  44.070000  44.070000  43.709999  43.709999  43.414669    2900
# 2019-07-18  43.610001  44.799999  43.529999  44.590000  44.288727   10700
# 2019-07-19  45.000000  45.480000  44.590000  44.590000  44.288727   18300
# ...               ...        ...        ...        ...        ...     ...
# 2020-07-08  62.189999  63.180000  61.480000  63.180000  63.180000   16600
# 2020-07-09  63.669998  65.400002  62.230000  64.809998  64.809998   47200
# 2020-07-10  65.000000  65.190002  63.410000  64.809998  64.809998   21100
# 2020-07-13  66.230003  67.699997  61.830002  61.900002  61.900002   56400
# 2020-07-14  60.740002  64.150002  59.590000  63.910000  63.910000   83100
#
# ...

# %%
# visualizing the Data
plt.figure(figsize=(12.5, 4.5))
plt.plot(USD, label = "USD")
plt.title("Yahoo Finances Adj Close Price")
plt.xlabel("July 2019 - July 2020")
plt.ylabel("Adj. Close Price USD ($)")
plt.legend(loc = "upper left")
plt.show()

# %%
print(USD.Close)
# Out:
# Date
# 2019-07-15    44.439999
# 2019-07-16    43.509998
# 2019-07-17    43.709999
# 2019-07-18    44.590000
# 2019-07-19    44.590000
# 2019-07-22    46.369999
# 2019-07-23    47.439999
# 2019-07-24    50.220001
# 2019-07-25    48.560001
# 2019-07-26    48.560001
# 2019-07-29    48.910000
# 2019-07-30    48.459999
# 2019-07-31    45.500000
# 2019-08-01    43.700001
# 2019-08-02    42.400002
# 2019-08-05    38.910000
# 2019-08-06    39.419998
# 2019-08-07    39.930000
# 2019-08-08    41.869999
# 2019-08-09    40.410000
# 2019-08-12    39.560001
# 2019-08-13    41.830002
# 2019-08-14    39.419998
# 2019-08-15    39.150002
# 2019-08-16    41.209999
# 2019-08-19    42.910000
# 2019-08-20    42.419998
# 2019-08-21    43.330002
# 2019-08-22    43.169998
# 2019-08-23    39.380001
#                 ...
# 2020-06-02    56.279999
# 2020-06-03    58.380001
# 2020-06-04    59.450001
# 2020-06-05    62.369999
# 2020-06-08    62.000000
# 2020-06-09    62.119999
# 2020-06-10    63.080002
# ...

# %%
from pandas_datareader import data as web

APEX = web.DataReader("APEX", data_source="yahoo", start="1995-1-1")

# %%
APEX.tail()
# Out:
#             High   Low  Open  Close     Volume  Adj Close
# Date
# 2020-07-17  0.65  0.62  0.64   0.63   364600.0       0.63
# 2020-07-20  0.65  0.62  0.64   0.64   279100.0       0.64
# 2020-07-21  0.65  0.62  0.65   0.63   237400.0       0.63
# 2020-07-22  0.71  0.62  0.63   0.68  1504500.0       0.68
# 2020-07-23  0.72  0.65  0.66   0.70   973400.0       0.70

# %%
APEX.head()
# Out:
#              High    Low   Open  Close  Volume  Adj Close
# Date
# 1995-01-03  7.500  6.375  6.375   7.50  2000.0   1.890395
# 1995-01-04  7.875  6.000  6.000   6.75  2500.0   1.701356
# 1995-01-05  6.000  6.000  6.000   6.00   300.0   1.512316
# 1995-01-06  8.250  8.250  8.250   8.25   100.0   2.079434
# 1995-01-09  6.000  6.000  6.000   6.00   300.0   1.512316

# %%
plt.figure(figsize=(15, 6))
plt.plot(APEX["Open"], label = "APEX")
plt.plot(APEX["Close"], label = "APEX")
plt.plot(USD["Open"], label = "USD")
plt.plot(USD["Close"], label = "USD")
plt.title("Yahoo Finances Open Price")
plt.xlabel("Jan 3rd 1995 - July 23nd 2020")
plt.ylabel("Adj. Close Price USD ($)")
plt.legend(loc = "upper left")
plt.show()
